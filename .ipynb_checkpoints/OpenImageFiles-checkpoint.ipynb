# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2

# %%
img = cv2.imread('superman.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (983, 1573, 3)

# %%
plt.imshow(img)

# %%
# MATPLOTLIB -> RGB RED, GREEN, BLUE
# OPENCV -> BLUE, GREEN, RED

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
img_gray = cv2.imread('superman.jpg', cv2.IMREAD_GRAYSCALE)
